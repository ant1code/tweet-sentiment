# %%
import pandas as pd
import numpy as np
import random

# %%
df = pd.read_csv('train.csv')
df = pd.DataFrame(data=df, columns=['text', 'sentiment'])
df = df.dropna()
df['sentiment'] = df['sentiment'].map({'positive': 2, 'neutral': 1, 'negative': 0})
df['my guess'] = 42

# %%
df.head(10)
df.shape
# Out:
# (27485, 3)

# %%
df.sample(10)
# Out:
#                                                     text  sentiment  my guess
# 9853   _Foster Just so i can see how they look with t...          1        42
# 22406   I used to love you lol...so awesome...I knew ...          2        42
# 20509  I dnt get to go play lasertag w/ my besties!  ...          0        42
# 25892   I still have a lot of time on my stupid contr...          0        42
# 1865    BTW, 'nathanfillion' is trying to beat his Fl...          1        42
# 20460  i'm going to sleepies, feel poorlies and pisse...          0        42
# 289    i need to see ...now! someone buy me a plane t...          1        42
# 9216    Then I'll need plenty of quizzes to get throu...          1        42
# 648     i think i ordered a few days after you. Maybe...          1        42
# 21523    i love you,i love you,i love you -you're the...          2        42

# %%
print(x)
# Out:
#  ohhhh excellent song..hello my friend!

# %%
# 0...negative
# 1...neutral
# 2...positive
n = random.randrange(1,27485,1)
x = df.iloc[n, 0]
guessed_sentiment = input(x)
if guessed_sentiment == "0":
    df.iloc[n, 2] = 0
    print(y)
    y = y+1
elif guessed_sentiment == "1":
     df.iloc[n, 2] = 1
     print(y)
     y = y+1
elif guessed_sentiment == "2":
     df.iloc[n, 2] = 2
     print(y)
     y = y+1
else:
    print("Fail.")
# Out:
#  awesome RONIN1212
# 51

# %%
print(df.iloc[n, :])
# Out:
# text          ohhhh excellent song..hello my friend!
# sentiment                                          2
# my guess                                           0
# Name: 7996, dtype: object

# %%
answers = df[ df['my guess'] != 42 ]

# %%
answers.head()
# Out:
#                                                    text  sentiment  my guess  \
# 303   I really ain't woth a ****. I can't do anythin...          0         0
# 1000  i love pink, and i don't care. today i shall n...          2         2
# 2187                      ahh retweet everything i say!          1         1
# 2601   Hey what's up? My name is Caleb and I'm your ...          1         1
# 2763                                        more coffee          1         1
#
#       correct
# 303         0
# 1000        0
# 2187        0
# 2601        0
# 2763        0

# %%
answers["correct"] = 0
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
answers['correct'] = np.where((answers['sentiment'] == answers['my guess']), "1", 0)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
answers
# Out:
#                                                     text  sentiment  my guess  \
# 303    I really ain't woth a ****. I can't do anythin...          0         0
# 1000   i love pink, and i don't care. today i shall n...          2         2
# 2187                       ahh retweet everything i say!          1         1
# 2601    Hey what's up? My name is Caleb and I'm your ...          1         1
# 2763                                         more coffee          1         1
# 3810   Dfizzy if you ever read this Uh i got one ques...          1         2
# 4126                                  just got home lng.          1         2
# 4247                                     misses  so much          0         0
# 4374   was laughed at today for being too hopeful wit...          0         0
# 4950   whatever. i give up, my phones about to die an...          0         0
# 5320                                    awesome RONIN121          2         2
# 5584   &quot;I will stumble.. I will fall down... But...          1         1
# 5680   http://twitpic.com/4j8yk - Thelma, Rebeca, Fer...          1         1
# 5881                    Working   But it's Fridaaaayyyyy          1         2
